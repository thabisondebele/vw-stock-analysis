# %%
import pandas as pd          # pd is the universal shorthand for pandas
import numpy as np           # np is the universal shorthand for numpy
import matplotlib.pyplot as plt  # plt is the standard shorthand
import seaborn as sns         # sns is the standard shorthand for seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/raw/Volkswagen_Stock.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv('../data/raw/Volkswagen_Stock.csv')
#
# File c:\vw_project\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\vw_project

# %%
import os
os.chdir(r'C:\vw_project\notebooks')
print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: C:\vw_project\notebooks

# %%
df = pd.read_csv(r'C:\vw_project\data\raw\Volkswagen_Stock.csv')

# %%
df = pd.read_csv('../data/raw/Volkswagen_Stock.csv')

# %%
print('Shape:', df.shape)
print('Columns:', df.columns.tolist())
df.head()
# Out:
# Shape: (7930, 25)
# Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Daily_Return_Pct', 'Daily_Range', 'MA_20', 'MA_50', 'MA_200', 'EMA_12', 'EMA_26', 'MACD', 'MACD_Signal', 'BB_Upper', 'BB_Lower', 'BB_Width', 'RSI_14', 'Volume_MA_20', 'Cumulative_Return_Pct', 'Year', 'Month', 'Quarter', 'Day_of_Week']
#          Date     Open     High      Low    Close  Volume  Daily_Return_Pct  \
# 0  1995-03-24  17.1538  17.2050  17.0000  17.4095       0               NaN
# 1  1995-03-27  17.6907  17.8952  17.5884  17.2050       0           -1.1746
# 2  1995-03-28  17.5884  17.6038  17.2050  17.2050       0            0.0000
# 3  1995-03-29  17.2050  17.2050  17.2050  17.2050       0            0.0000
# 4  1995-03-30  17.1794  17.7930  17.1794  17.7418      10            3.1200
#
#    Daily_Range  MA_20  MA_50  ...  BB_Upper  BB_Lower  BB_Width  RSI_14  \
# 0       0.2050    NaN    NaN  ...       NaN       NaN       NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7930 entries, 0 to 7929
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   7930 non-null   str
#  1   Open                   7930 non-null   float64
#  2   High                   7930 non-null   float64
#  3   Low                    7930 non-null   float64
#  4   Close                  7930 non-null   float64
#  5   Volume                 7930 non-null   int64
#  6   Daily_Return_Pct       7929 non-null   float64
#  7   Daily_Range            7930 non-null   float64
#  8   MA_20                  7911 non-null   float64
#  9   MA_50                  7881 non-null   float64
#  10  MA_200                 7731 non-null   float64
#  11  EMA_12                 7930 non-null   float64
#  12  EMA_26                 7930 non-null   float64
#  13  MACD                   7930 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  7930.000000  7930.000000  7930.000000  7930.000000  7.930000e+03
# mean    112.856102   114.505508   111.134678   112.797557  9.671652e+05
# std      67.426068    69.107623    65.953704    67.418700  2.467386e+06
# min      17.153800    17.205000    17.000000    17.205000  0.000000e+00
# 25%      53.150000    53.870000    52.282500    53.200000  6.808475e+04
# 50%     110.325000   112.130000   108.700000   110.100000  1.902820e+05
# 75%     155.400000   157.287500   153.915000   155.600000  1.455133e+06
# max     520.000000   635.000000   491.000000   520.000000  1.672419e+08
#
#        Daily_Return_Pct  Daily_Range        MA_20        MA_50       MA_200  \
# count       7929.000000  7930.000000  7911.000000  7881.000000  7731.000000
# mean           0.055331     3.370831   112.924272   113.124163   114.163468
# std            2.809585     6.321663    66.964782    66.462505    64.044665
# ...

# %%
df.isnull().sum()
# Out:
# Date                       0
# Open                       0
# High                       0
# Low                        0
# Close                      0
# Volume                     0
# Daily_Return_Pct           1
# Daily_Range                0
# MA_20                     19
# MA_50                     49
# MA_200                   199
# EMA_12                     0
# EMA_26                     0
# MACD                       0
# MACD_Signal                0
# BB_Upper                  19
# BB_Lower                  19
# BB_Width                  19
# RSI_14                    88
# Volume_MA_20              19
# Cumulative_Return_Pct      0
# Year                       0
# Month                      0
# Quarter                    0
# Day_of_Week                0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index('Date')
